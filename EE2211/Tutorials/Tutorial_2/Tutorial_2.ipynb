# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Question 1:

df = pd.read_csv('Tutorial 2 supp government-expenditure-on-education.csv')
plt.plot(df['year'], df['total_expenditure_on_education'], label='Spending')
plt.xlabel('Year')
plt.ylabel('Total expenditure on education (% of GDP)')
plt.title('Government expenditure on education over time')
plt.legend()
plt.show()

# %%
#Question 2:
df = pd.read_csv('AnnualMotorVehiclePopulationbyVehicleType.csv')

df2 = df[df['category'] == 'Buses']
df2 = df2[df2['year'] <= 2017]

omnibuses = df2[df2['type'] == 'Omnibuses']
excursion_buses = df2[df2['type'] == 'Excursion buses']
private_buses = df2[df2['type'] == 'Private buses']
plt.plot(omnibuses['year'], omnibuses['number'], label='Omnibuses')
plt.plot(excursion_buses['year'], excursion_buses['number'], label='Excursion Buses')
plt.plot(private_buses['year'], private_buses['number'], label='Private Buses')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Number of vehicles')
plt.title('Motor Vehicle Population by Type')
plt.show()

# %%
#Question 3:
from sklearn.datasets import load_iris

iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
pd.plotting.scatter_matrix(iris_df, figsize=(10, 10))
plt.suptitle('Scatter Matrix of Iris Dataset')
plt.show()

# %% [markdown]
# ### Question 4
#
# a. Data with higher numerical values may be weighted as more significant by the model
# b. Normalize data for each column before supervised learning

# %%
#Question 5:

df = pd.read_csv('pima-indians-diabetes.data.csv', header=None)
df.describe()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
zeros1 = (df[0] == 0).sum()
zeros2 = (df[1] == 0).sum()
zeros3 = (df[2] == 0).sum()
zeros4 = (df[3] == 0).sum()
zeros5 = (df[4] == 0).sum()

print(f'Number of zeros in column 0: {zeros1}')
print(f'Number of zeros in column 1: {zeros2}')
print(f'Number of zeros in column 2: {zeros3}')
print(f'Number of zeros in column 3: {zeros4}')
print(f'Number of zeros in column 4: {zeros5}')
# Out:
# Number of zeros in column 0: 111
# Number of zeros in column 1: 5
# Number of zeros in column 2: 35
# Number of zeros in column 3: 227
# Number of zeros in column 4: 374

# %%
df.replace(0, np.nan)
# Out:
#         0      1     2     3      4     5      6   7    8
# 0     6.0  148.0  72.0  35.0    NaN  33.6  0.627  50  1.0
# 1     1.0   85.0  66.0  29.0    NaN  26.6  0.351  31  NaN
# 2     8.0  183.0  64.0   NaN    NaN  23.3  0.672  32  1.0
# 3     1.0   89.0  66.0  23.0   94.0  28.1  0.167  21  NaN
# 4     NaN  137.0  40.0  35.0  168.0  43.1  2.288  33  1.0
# ..    ...    ...   ...   ...    ...   ...    ...  ..  ...
# 763  10.0  101.0  76.0  48.0  180.0  32.9  0.171  63  NaN
# 764   2.0  122.0  70.0  27.0    NaN  36.8  0.340  27  NaN
# 765   5.0  121.0  72.0  23.0  112.0  26.2  0.245  30  NaN
# 766   1.0  126.0  60.0   NaN    NaN  30.1  0.349  47  1.0
# 767   1.0   93.0  70.0  31.0    NaN  30.4  0.315  23  NaN
#
# [768 rows x 9 columns]

# %% [markdown]
# ### Question 6:
# Ordinal Data
